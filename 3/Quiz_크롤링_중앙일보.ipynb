# %% [markdown]
# # 중앙일보

# %%
import requests
import lxml.html
from urllib.parse import urljoin

board_url = 'http://news.joins.com/brandnews?cloc=joongang|home|biz'
response = requests.get(board_url)
#response.content.decode('utf8')

root = lxml.html.fromstring(response.content)
root.xpath('.//*[@id="content"]/div/ul/li')[0].text_content()

node = root.xpath('.//*[@id="content"]/div/ul/li/strong')[0].text_content()
node
# Out:
# <Element html at 0x4b94ea8>

# %%
for node in root.xpath('.//*[@id="content"]/div/ul/li/strong/a'):
    
    # 게시물 리스트 제목 출력
    print(node.text_content())

    # 게시물 본문 URL
    main_text_url = urljoin(board_url, node.attrib['href'])
    print(main_text_url)
    print()
    
    # 게시물 본문 조회 및 출력
    response_main = requests.get(main_text_url)
    root_main_text = lxml.html.fromstring(response_main.content)
    main_text = root_main_text.xpath('.//div[@id="article_body"]')[0].text_content()
    print(main_text)
    print('━'*30)
# Out:
# 제니스카운티, 소년소녀가장돕기 ‘제1회 아마추어 골프대회’ 개최
# http://news.joins.com/article/19875586
#
#
# 제니스카운티는 오는 4월14일 롯데스카이힐 제주C.C에서 소년소녀가장돕기 ‘제1회 제니스카운티배 아마추어 골프대회’를 개최한다고 밝혔다. 이번 골프대회는 제주지역 소년소녀가장을 후원하기 위해 마련됐으며, 참가자격은 제주도민을 우선으로 하며 순수 아마추어 골퍼라면 연령제한 없이 참여 가능하다. ‘제1회 제니스카운티배 아마추어 골프대회’는 총상금 2천만 원 상당의 부상이 주어지며 선착순으로 144명 36개팀이 참가할 예정이다. 경기방식은 18홀 샷건(동시 티업) 스트로크 플레이로 진행되며 대한골프협회 승인 골프규칙과 골프장 로컬룰을 적용한다. 제니스카운티 관계자는 “이번 골프대회는 제니스카운티의 사회 소외계층 지원과 다양한 사회환원 사업의 일환으로 기획됐다”며 “척박한 환경에서 어렵게 생활하고 있는 제주지역 소년소녀가장들에게 조금이나마 보탬을 주고자 마련한 행사이니 만큼 적극적인 참여 바란다”고 전했다. <이 기사는 본지 편집 방향과 다를 수 있으며, 해당기관에서 제공한 보도 자료입니다.>
#
#
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# “더클래스 효성, 4월 Young & Active 프로모션으로 젊고 활동적인 봄맞이 라이프스타일 제안”
# http://news.joins.com/article/19857920
#
#
# Young & Active 이미지차별화 된 서비스로 고객만족 극대화를 위해 노력해 온 메르세데스-벤츠 공식 딜러 더클래스 효성(대표이사 배기영)이 4월 한달 간  ‘Young & Active프로모션‘ 을 진행한다.  ‘Young & Active‘ 프로모션은 고객들에게 색다른 경험을 통한 일상 충전을 위해 NCC(New Compact Car), SUV, The CLS 전 차종 출고 고객을 대상으로 55만원 상당의 고프로 액션캠(action cam, 히어로 4 실버)을 증정한다. 특히 이번 프로모션은 따뜻해진 날씨로 야외활동이 잦아짐에 따라 젊고 활기찬 레저활동을 지원하기 위해 일반 카메라가 아닌 액션캠을 제공, 나만의 특별한 라이프스타일을 위해 기획되었다. 액션캠은 나들이, 등산, 자전거, 스카이다이빙 등 레저 스포츠 또는 야외활동을 즐기는 동시에 영상을 촬영할 수 있게 만든 장비로 이번 프로모션에 증정하는 기기는 데이터 무선전송, 야간 촬영, 인터벌 촬영이 가능한 최신 기종이다. 더클래스 효성은 4월 고객들의 야외활동이 많아 차량 운행이 잦아짐으로써 안전한 운행을 위한 ‘Refresh Service Campaign‘을 진행 중에 있다. 타이어 및 차량 냉각수 점검 등 총 12가지 항목에 대한 무상점검 서비스를 진행하고 있으며, 이밖에 엔진오일 패키지 교환 시 살균 훈증캔 증정을 비롯해 유상 수리 시 금액에 따라 메르세데스-벤츠 정품 액세서리 및 서비스 쿠폰을 증정하고 있다. 이와 함께 분당 정자 전시장 리뉴얼 공식 오픈을 앞두고 이를 기념해 23일 내방객 및 기존 고객들을 대상으로 고객 체험행사를 개최한다. The new generation A-Class, B-Class, CLA, GLA 등 NCC 전 모델 전시와 시승행사를 운영하며, B-Class 전시차량 이벤트 및 다양한 엔터테인먼트를 비롯해 간단한 식사와 기념품을 제공한다. 더클래스 효성 배기영 대표이사는 “더클래스 효성 고객들에게 보다 젊고 역동적인 라이프스타일을 제안함으로써 반복되는 일상에서 탈출하는 계기가 되었으면 한다“며  “자동차 운행이 많은 봄철을 맞아 고객들의 안전 운행을 비롯한 무상 점검서비스 등 최상의 서비스를 지속적으로 선보일 계획이다“고 했다.  한편, 더클래스 효성은 4월 1일부터 30일까지 한달 간 더클래스 효성의 지정된 전시장의  NCC 전시 차량 인증샷을 등록하는 고객에게 추첨을 통해 메르세데스-벤츠 컴팩트카 기념품을 증정하는 ‘컴팩트카 인증샷 이벤트‘를 진행 중에 있다. 자세한 내용은 당사 홈페이지 (www.theclasshyosung.com)를 통해 확인할 수 있다.<이 기사는 본지 편집 방향과 다를 수 있으며, 해당기관에서 제공한 보도 자료입니다.>
#
#
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 천하제일의 산수, 계림
# http://news.joins.com/article/19845024
#
#
#  넓고 볼거리가 많은 중국에서도 ‘계림의 산수가 천하제일이다(桂林山水甲天下)’라고 칭송 받는 곳, 바로 계림이다.  계림(Guilin, 桂林)은 중국의 남서쪽, 광시장족자치구(廣西壯族自治區)에 위치한 도시다. 예부터 계수나무가 많은 지역이라 해서 계수나무 숲으로 불렸다. 1년 내내 따뜻한 날씨를 자랑하며 한 폭의 동양화를 연상시키는 그림 같은 풍경을 보기 위해 세계 여행자들의 발길이 끊이지 않고 있다.    중국 화폐 20위엔의 뒷면에는 중국 시인과 화가들의 글과 그림의 소재가 되어왔던 계림의 풍경이 담겨있다. 계림을 중심으로 펼쳐진 3만 6,000여개가 넘는 봉우리들이 어우러진 경치는 여행자들의 감탄을 자아낸다.  계림 관광의 하이라이트는 바로 이강 유람이다. 이강은 지류까지 총 430여km로, 계림 여행을 하는 동안은 어디로 향하더라도 이강을 계속 만나게 된다. 고즈넉한 이강 유람을 즐기며 끝없이 펼쳐진 산봉우리를 바라보고 있으면 어느새 마음이 한없이 편안해지고 마치 신선이 된 기분이 든다. 밤이 되면 이강은 화려하게 변신한다. 양강사호(兩江四湖) 유람은 양강(이강,도화강)과 사호(목룡호,계호, 용호, 삼호)로 이루어진 인공호수를 유람하며, 대표적인 금탑과 은탑을 비롯한 다양한 볼거리들과 함께 이강의 어부들이 계림의 명물"가마우지(낚시도우미새)"를 이용해 고기를 낚는 전통 낚시 퍼포먼스도 보여준다.  계림에서 차로 1시간30분 떨어진 곳에 가면 배낭여행자들의 천국으로 불리는 양삭에 도착한다. 가는 길에는 중국 소수민족의 생활 풍습을 볼 수 있는 세외도원과 빼어난 경치로 수많은 사진 작가들의 발길을 끄는 상공산이 있다. 밤이 되면 중국의 거장 장예모 감독이 연출한 ‘인상유삼저’ 야외 공연도 즐길 수 있다. 계림의 산봉우리를 배경으로 이강 위에서 펼쳐지는 이 공연은 엄청난 스케일과 화려함을 자랑한다. 그리고 세계 각 국의 배낭여행자들이 모이는 활기찬 서가재래시장도 빼놓을 수 없는 즐거움이다.  계림에서 차를 타고 3시간 가면 용승이 나오는데 중국 최대의 계단식 논 ‘용척제전’을 만날 수 있다. 지금도 소수민족들의 생활 터전인 용척제전은 해발 1,916m의 산자락에 우리가 흔히 다랭이 논이라 부르는 논이 산 전체를 뒤덮고 있는 곳이다. 그 모습이 마치 한 마리의 용이 꿈틀거리는 모습이라서 용척제전으로 불리게 됐다. 여기서 조금 더 깊은 산 속으로 들어가면 조용한 온천 호텔이 하나 있는데 그 곳에서는 지하 1,200m에서 솟아나는 천연 온천인 ‘용승온천’을 즐길 수도 있다.      계림은 아시아나항공(OZ), 중국동방항공(MU)이 직항으로 운항하고 있고, 대한항공(KE) 난닝 노선을 통해서도 갈 수 있다. 계림으로의 여행을 생각한다면 하나투어 홈페이지 또는 대표번호 1577-1212를 통해서 예약 가능하다.<이 기사는 본지 편집 방향과 다를 수 있으며, 해당기관에서 제공한 보도 자료입니다.>
#
#
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 페이스북/유튜브 동영상 광고 집계 in 리서치애드
# http://news.joins.com/article/19842266
#
#
# 인터넷상의 노출형 광고 통계 데이터 서비스를 체계화 하여 제공하는 (주)리서치애드는 2008년 이벤트 통계 데이터 및 2013년 모바일 광고 통계 데이터 서비스에 이어 오는 2016년 4월 1일 신규 서비스인 '동영상 통계 데이터 서비스' 를 선보인다고 밝혔다.소셜네트워크서비스 페이스북, 동영상 사이트 유튜브/ 판도라TV,  포털사이트 네이버 TV캐스트/ 다음 TV팟, 지상파 사이트 iMBC/ KBS/ SBS 등의 동영상 광고를 집계하여 제공하는 (주)리서치애드 동영상 서비스는 페이스북/유튜브 같은 글로벌 사이트들의 동영상 매출 추세와 동영상 광고를 선호하는 광고주들의 광고 트렌트를 분석할 수 있는 장점을 보유, 체계적이고 유의미한 동영상 통계 데이터 서비스가 될 것으로 업계 담당자는 전망했다.특히, (주)리서치애드는 '동영상 클립 서비스를 제공하는 SMR(Smart Media Representative) 을 통해 진행된 광고를 쉽게 구분하여 볼 수 있으며, 동영상 광고를 진행한 광고주들의 모바일 및 PC 집계 내역까지 확장하여 데이터 검색이 가능하다'고 전했다.㈜리서치애드의 광고 자동수집엔진인 'AD-Collector'를 통해 수집된 광고들은 광고분류통계시스템(AD-Classification and Statistics System) 및 광고비 산정을 거쳐 리서치애드 사이트(www.researchad.com)를 통해 데이터를 서비스 하고 있으며, 신규 런칭된 동영상 서비스는 오픈 베타 기간인 4월 한 달 동안 무료로 사용이 가능하다.[문의: mkt@researchad.com, 02-546-9692]<이 기사는 본지 편집 방향과 다를 수 있으며, 해당기관에서 제공한 보도 자료입니다.>
#
#
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 국내 최초 언론사 내 네이티브형 동영상광고 상품 출시
# http://news.joins.com/article/19839775
#
#
#  동영상 광고 시장은 변화하고 있다. 단순히 유튜브에 영상을 올리는 방식이 아니라 컨텐츠와 연계하여 네이티브형 광고 플랫폼을 선보이거나 기존에 없던 영역을 새롭게 만들어 유저들의 주목도를 높이는 등의 형태로 변화가 일어나고 있는 상황이다. 이렇듯 유저들의 시선을 잡아둘 수 있는 다양한 노력들이 이루어지는 가운데 지난 3월 인터웍스미디어에서 출시 된 기사 컨텐츠 내 동영상 광고 네트워크 플랫폼 ‘인터플레이’ 동영상 상품이 인기를 끌 전망이다.  인터웍스미디어는 국내 최초로 언론 매체 동영상 광고 네트워크 플랫폼인 ‘인터플레이’를 런칭 하였다. 인터플레이는 기존에 없던 기사 컨텐츠 영역 중간에 새롭게 영역을 확장하여 동영상이 자동으로 재생 되는 동영상 광고 네트워크 플랫폼이다. 언론사 내 가장 큰 광고 영역 사이즈인 640*360 사이즈로 구현되어 특히 높은 주목도를 자랑한다. 타사의 경우 영상 컨텐츠를 시청하기 위해 프로그램 앞/뒤로 강제 재생되던 방식과는 달리 유저들의 시선을 자연스럽게 확보하면서도 자발적인 재생이 가능한 독보적인 상품이다.* Sample page: http://www.interworksmedia.co.kr/test/sample.html 인터플레이의 최대 장점은 한국전자통신연구원(ETRI)에서 개발한 “지능형 문맥기반 광고추천 기술WiseCM v1.0” 을 활용한 동영상 상품으로써 기사와 관련된 광고가 노출되어 유저의 거부감을 최소화하고 컨텐츠와 동영상이 어우러지는 컨텐츠형 Native AD 구현이 가능하다는 점이다. 또한, 광고주가 원하는 특정 기사를 선별하여 고정 노출하는 형태도 가능하며 인터플레이를 클릭한 유저에게 배너를 다시 노출할 수 있으며 기존 인터웍스의 대표 상품인 오디언스 타겟팅, 리타겟팅 등과 마찬가지로 정교한 타겟팅 기술력을 바탕으로 동일한 타겟팅이 적용 된 인터플레이 상품 역시 오는 상반기 내 만나볼 수 있을 것으로 기대된다. ㈜인터웍스미디어 이남영 이사는 “인터플레이는 영상이 3초 이상 재생된 뒤 과금 되는 방식으로 효율적인 노출이 가능하며, 평균 5%의 높은 CTR과 58%에 해당하는 VTR을 보이며 출시 이후 광고주로부터의 만족도가 높다”고 전하며 “현재 조선일보, 한국경제 등 프리미엄 언론사 매체와의 제휴 외 향후 다양한 매체들과 제휴를 통해 6월내 모바일상품도 런칭 예정이다”라고 밝혔다.상품문의: 02-550-0225 / hrpark@iwmedia.co.kr<이 기사는 본지 편집 방향과 다를 수 있으며, 해당기관에서 제공한 보도 자료입니다.>
#
#
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 중대질병 보장, 생활자금 보조 … '반퇴 시대' 든든한 동반자
# http://news.joins.com/article/19838030
#
#
# 무조건 오래 사는 것은 별로 바람직하지 않다. 병치레해가며 장수한다는 것은 일종의 재앙이다. 본인에게는 육체적 고통을 주고, 가족에겐 의료비와 입원비 지출로 경제적 부담을 준다. 아프지 않고 오래 사는 건강수명이 길어야 진정한 장수라고 할 수 있다. 한국인은 건강수명이 그리 길지 않다. 노후를 아픈 상태로 보내는 기간이 평균 10년이나 된다."은퇴 전 주계약 1억원 가입 CI·LTC 때 일시금 5000만원 생활비 3년간 월 100만원"나이 들수록 병원에 갈 일이 많아진다. 우리 나라 65세 이상 노인인구 진료비는 가파르게 증가하고 있다. 2014년 65세 이상 노인인구가 지출한 건강보험 진료비는 19조9000억원으로 전체 진료비의 36.3%를 차지했다. 국민건강보험공단에 따르면 2060년이 되면 65세 이상 노인 진료비가 최소 229조5000억원에서 최대 337조1000억원까지 될 것으로 추산된다. 노인 진료비가 국내총생산(GDP)에서 차지하는 비중도 2014년 1.34%에서 2060년 최대 5.67%까지 확대된다.  나라살림에도 부담을 주지만 진료비는 개인에게도 큰 짐이다. 우리나라 64세 이상 노인의 1인당 연간 진료비는 2008년 208만원에서 2014년 333만원으로 크게 늘었다. 65세 미만 연령층보다 4.2배나 많다. 월평균소비지출 가운데 의료비가 차지하는 비중도 65세 이상 가구는 전체 가구(6.4%)의 2배가 넘는 15.3%에 달한다. 국민의 생애 의료비 중 65세 이후 발생하는 의료비 비중이 50%를 넘는 건 그만큼 노후에 의료비 지출이 집중된다는 의미다. 그중에서도 암과 치매가 가장 무섭다.멀티플랜교보통합CI보험국립암센터에 따르면 암환자 1인당 치료 비용은 간암 6622만원, 췌장암 6371만원, 폐암 4657만원에 달한다. 암 진단을 받으면 83.5%가 일을 그만두기 때문에 가정의 경제적 부담은 가중될 수밖에 없다. 중대질병(CI)과 치매, 일상생활장해 같은 장기간병상태(LTC) 발생에 대비해야 한다. 교보생명 ‘멀티플랜교보통합CI보험’은 CI와 LTC까지 보장하는 전천후 상품이다. CI나 LTC발생 시 진단보험금과 함께 매월 가족생활자금까지 수령할 수 있다. 주계약 1억원에 가입하고, 경제활동기에 CI나 LTC가 발생하면 일시금으로 5000만원의 진단보험금을, 가족생활자금으로 3년간 월 100만원씩 각각 받을 수 있다. CI나 LTC가 발생하면 치료비가 많이 들고 경제활동을 계속하기 어려운데, 고액의 치료비는 물론 가장의 소득상실에 따른 생활비까지 지원해 가족의 안정된 생활을 돕도록 했다. CI와 LTC 발병으로 사망하면 2000만원을 추가로 지급한다.  아프지 않고 은퇴한다면 은퇴 시점부터 5년간 매년 1000만원씩 건강생활자금을 받을 수 있다. 은퇴 후 건강관리 및 생활안정자금으로 활용하면 된다. 기존 보험은 사망하거나 아파야만 보험금을 받을 수 있었지만 이 상품은 살아 있을 때 보장 혜택을 받고 싶어 하는 고객의 요구를 반영해 보험금 일부를 미리 지급하는 것이다. 교보생명 관계자는 “평균수명 증가로 ‘유병 장수’ 시대가 다가오면서 치료비는 물론 생활자금까지 받을 수 있는 상품이 필요하다고 봤다”며 “경제활동기에는 CI와 LTC를 집중적으로 보장하고 은퇴 후에는 생활안정을 도와주는 다목적 상품”이라고 설명했다. 배우자, 자녀 3명도 보장보험 하나로 본인을 비롯해 배우자와 자녀 3명 등 총 5명까지 온 가족이 CI·입원비·실손 의료비 등 다양한 보장을 받을 수 있도록 한것도 장점이다. 두 번째 CI보장 특약 가입 시 중대한 암 등 다른 CI가 재발해도 한 번 더 보장받을 수 있다. 보험 가입 후에 가정 구성원의 변화에 따라 배우자나 자녀를 피보험자로 추가할 수 있고, 보험 가입 이후 필요한 특약보장을 설정할 수 있다. 15세부터 60세까지 가입할 수 있다. 주계약 보험 가입 금액에 따라 2.5%에서 최대 4%까지 보험료 할인 혜택을 준다. 주계약 7000만원 이상 가입하면 교보생명만의 차별화된 종합건강관리서비스 ‘교보헬스케어서비스(LTC형)’를 받을 수 있다. 평상시 건강 관리부터 질병 발생 시 치료까지 지원하는 선진국형 고객 관리 서비스다. 문의 1588-1001◆중대질병(CI·Critical Illness)=암·뇌졸중·급성심근경색증 또는 관상동맥우회술, 5대 장기이식수술 등 중대한 질병 또는 중대한 화상.◆장기간병상태(LTC·Long Term Care)=일상생활장해상태(ADL) 또는 중증치매상태(Dementia).장원석 기자 jang.wonseok@joongang.co.kr
#
#
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# '액티브 시니어'의 음악 취미활동 응원합니다
# http://news.joins.com/article/19838020
#
#
# 서울 낙원악기상가 야외공연장에서 50~60대가 모여 취미활동으로 닦은 건반·기타·색소폰 연주 실력을 뽐내고 있다.한국방송광고진흥공사는 ‘2015 소비자 행태조사’에서 2016년 주목해야 할 소비자로 ‘액티브 시니어(active senior)’를 꼽았다. 액티브 시니어는 탄탄한 경제력과 시간적 여유가 있는 은퇴세대로 여가생활에 아낌없이 투자하는 활동적인 노년층을 말한다. 액티브 시니어의 취미활동을 응원하기 위해 악기 전문매장이 모인 ‘낙원악기상가’가 나섰다."55세 이상 참가자 모집 기타·건반·색소폰 연주 두 달간 1대1 무료 강습"3년 전 정년퇴직한 김동운(61)씨는 요즘 색소폰을 부는 재미에 푹 빠졌다. 은퇴 후 여유시간이 많아지면서 ‘평소 악기 하나는 배워봐야지’ 했던 생각을 실천에 옮겼다. 김씨는 “처음엔 색소폰 소리가 잘 안 나서 힘들었지만 쉬운 곡부터 차츰 연주할 수 있게 돼 생활에 활기가 돈다”며 “기타나 아코디언 같은 다른 악기도 도전해 볼 생각”이라고 말했다.악기 연주로 뇌 노화 예방악기 연주는 두뇌 개발은 물론 노화 예방에 효과적이라는 연구결과가 있다. 악기를 연주하면 두뇌의 신경세포 집단인 회백질이 늘어나고 좌뇌와 우뇌 사이의 신경세포 연결이 활발해진다. 과거엔 악기 연주가 어린이 두뇌 발달에 미치는 영향이 주로 연구됐으나 최근엔 성인은 물론 노년층에 대한 긍정적인 효과도 확인되고 있다.  뇌는 나이가 들어도 완전히 굳어버리진 않기 때문에 악기를 연주하면서 뇌를 자극하면 젊음을 오래 유지할 수 있다는 것이다. 특히 악기 연주는 청각·시각·촉각 등 여러 감각을 동시에 자극하기 때문에 뇌의 탄력성을 유지하는 데 좋다고 알려져 있다. 뇌를 젊게 유지하는 법, 치매 예방 요령에 악기 배우기가 빠지지 않는 이유도 이 때문이다.  실제로 300여 개의 다양한 악기 매장이 모인 서울 낙원동 낙원악기상가엔 악기를 둘러보러 온 50, 60대가 부쩍 늘었다. 색소폰과 아코디언이 진열된 2, 3층 매장뿐 아니라 4층의 합주실에서 악기를 배우는 액티브 시니어를 쉽게 만날 수 있다.  낙원악기상가는 올해부터 ‘반려악기 캠페인’을 진행한다. 남녀노소 구분 없이 악기를 평생을 함께하는 동반자나 친구와 같은 취미로 만들어 보자는 취지로 기획됐다. 50년 가까이 한국 악기시장을 이끌어 온 낙원악기상가는 악기 연주가 삶의 낙으로 즐기기에 충분한 가치가 있다는 것을 적극적으로 알릴 계획이다.17일까지 신청 접수자녀 결혼식이나 자신의 은혼식·금혼식 때 직접 악기를 연주할 수 있도록 1대 1 개인강습을 통해 단기간에 속성으로 배울 수 있는 ‘축주 선물 강습 프로그램’을 마련했다. 이달 5일부터 17일까지 55세 이상 액티브 시니어를 대상으로 사연 신청을 받아 악기 강습을 받을 시니어를 모집한다. ‘우리들의 낙원상가’ 공식 블로그(http://blog.naver.com/enakwon)를 통해 신청하면 된다.  기타·건반·색소폰 중 자신이 원하는 악기를 선택한 후 사연을 작성해 응모하면 된다. 당첨자는 2개월에 걸쳐 주 2회씩 총 16회에 걸쳐 전문 강사의 1대 1 강습을 받을 수 있다. 강습이 끝나는 6월 말께는 낙원악기상가 4층에 마련된 야외공연장 ‘아트라운지 멋진 하늘’에서 지인들을 초대해 그동안 연습한 솜씨를 뽐낼 수 있는 공연 기회도 마련할 계획이다. 낙원악기상가 최용구 팀장은 “인생의 소중한 순간에 가족에게도 특별한 추억이 될 것으로 기대한다”고 말했다.  낙원악기상가는 또 20~30대 젊은 직장인을 대상으로 한 ‘미생 응원 이벤트’와 국내 거주 외국인을 대상으로 ‘외국인 서포터즈(Nakwonsupporters)’ 프로그램을 진행하고 있다. 캠페인에 대한 자세한 내용은 ‘우리들의 낙원상가’ 공식 페이스북(www.facebook.com/nakwonmusic)과 블로그에서 확인할 수 있다.낙원악기상가 악기 강습 프로그램 참여 기회를 드립니다.응모 마감 4월 17일 당첨 발표 4월 19일중앙일보 독자 여러분에게 낙원악기상가 1대 1 강습 프로그램에 참여할 기회를 드립니다. 55세 이상 중앙일보 독자 3명을 선정해 2개월 동안 악기를 배울 수 있도록 지원합니다. 중앙일보 고객멤버십 JJ라이프(jjlife.joongang.co.kr)에서 응모하시면 됩니다. 당첨자는 사이트에 별도 공지하고 휴대전화로 개별 통보합니다. 문의 1588-3600글=한진 기자 jinnylamp@joongang.co.kr, 사진=프리랜서 조상희
#
#
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [프라임PEET] 덕성여대·동덕여대·숙명여대·이화여대 약대생과 함께하는 토크쇼 개최
# http://news.joins.com/article/19837168
#
#
# 프라임PEET가 주최하는 약대 입시 토크쇼의 여섯 번째 시리즈 “여대 약대 입시 Special 토크쇼”가 4월 30일 토요일 14시 이화여대 이화삼성교육문화관에서 개최된다. 프라임PEET 약대 입시 토크쇼는 2015년 11월 첫 개최 이후 매달 대치동, 목동, 신촌 등에서 5회에 걸쳐 1300여 명 이상의 학부모와 수험생이 참석하면서 약대 합격을 위한 대표적인 정보 시리즈로 자리 잡았다.서울 지역에 소재한 8개 약대 중 절반인 4개가 여대에 개설되어 있어서 여학생들에게 수도권 약대 진학의 문호는 보다 넓은 편이다. 여대 약대는 서류로 100% 전형하는 대학(이화여대 우선 선발)부터 PEET 성적 반영 비중이 절대적인 대학(동덕여대, 덕성여대)까지 고루 분포되어 있다. 따라서 합격을 위하여 본인의 강점을 잘 살릴 수 있는 로드맵을 설계하는 것이 무엇보다 중요하다.이번 설명회에서는 덕성여대, 동덕여대, 숙명여대, 이화여대 약대 합격자들의 연령, 출신 대학, GPA, PEET 성적, 토익 점수 등 구체적인 데이터를 바탕으로 한 유형별 성공전략이 제시된다. 또한 4개 여대 약대의 재학생들이 참석하여 직접 체감하였던 여대 약대 입시의 경향을 공개할 예정이며, 1:1 멘토링 또한 진행될 예정이다. 특히 이번 설명회에는 숙명여대 약대 입시 관계자가 직접 참석할 예정이어서 이목이 더욱 집중되고 있다.약대 입시 전문 교육기관 프라임PEET 유준철 대표는 “숙명여대 약대는 서류 반영 비중이 높고, 5과목에 걸쳐 총 15학점의 선수 과목 이수를 의무화하는 등 차별화된 평가 방식으로 수험생들의 문의가 가장 많은 대학 중 하나”이라며 “숙명여대 약대 입시 관계자에게 직접 듣고 질문할 수 있는 이번 기회를 통해 보다 대학이 원하는 인재상에 맞추어 입시를 준비를 할 수 있을 것이라고 기대한다”라고 말했다.   * 대상 : 여대 약대 입학을 희망하는 학생과 학부모* 일정 : 4월 30일 14시* 장소 : 이화여자대학교 이화삼성교육문화관* 예약 접수 : www.pmd.co.kr / (02) 521-8026<이 기사는 본지 편집 방향과 다를 수 있으며, 해당기관에서 제공한 보도 자료입니다.>
#
#
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 남성에게 꼭 필요한 6가지 기능을 단 한 알에 담아내…
# http://news.joins.com/article/19837156
#
#
# ▶ 하루 한알! 중년 남성들이여, 활력을 되찾아 보자! 과학이 발달하면서 이젠 100세 시대를 맞이했다. 고령화 사회가 되면서 자연스럽게 중년 남성들은 건강에 많은 관심을 가지게 된다. 중년 남성들은 적절한 운동과 더불어 전립선 건강, 지구력 증진에 도움을 줄 수 있는 건강기능식품을 섭취해야 남들보다 더 오래갈 수 있다. 남자의 생활의 활력을 도와줄 뉴홈런2가 전 세계적으로 인기를 끌고있다. 뉴홈런2 : 2016 두바이 헬스케어 세계박람회▶ 스페인, 브라질, 독일, 러시아, 두바이 등 ‘홈런2’ 세계 7개국 박람회 출품 뉴홈런2는 이번 2016년 1월 26일에 열린 두바이 세계박람회에도 참가하였다. 세계박람회는 선진 회사들이 서로의 신제품을 선보이며 기술력을 뽐내는 박람회이다. 두바이 박람회에서 확인된 전세계 중년 남성들의 공통관심사는 생활의 활력이다. 외국의 중년 남성들도 자신의 전성기 시절을 떠올리며 건강을 되찾으려 노력하고 있다. 뉴홈런2는 중년남성의 건강기능식품으로 전 세계인이 모인 현지에서 중년 남성들에게 폭발적 반응을 얻으며 굉장한 인기를 끌었다.  ▶ 풍부해진 부원료, 업그레이드 된 ‘뉴홈런2’ 주원료: 쏘팔메토열매추출물, 옥타코사놀, 아연, 비타민B2, 망간과부원료: 야관문(비수리), 숙지황, 산약, 복령, 두충, 인삼열매, 복분자, 마카, L-아르기닌, 산수유 전립선건강, 지구력보강, 에너지보강, 뼈건강/항산화, 정상적인 면역기능에 도움을 주는 뉴홈런2는 따로따로 각각의 건강기능식품을 챙겨먹을 필요없이 하루 한알로 중년남성의 건강을 챙길 수 있다. ▶ 소비자 가격부담 덜고, 시장성을 열다.  뉴홈런2는 사전광고심의를 통과하고 해외로 수출하는 건강기능식품이다. ㈜한국코러스제약 건강기능식품사업부에서 제조하여 믿음이 가고, 식약처 인정 원료를 사용하면서 퀄리티는 유지, 저마진 정책으로 가격은 소비자들의 부담을 확실하게 줄였다. 공식쇼핑몰 싹에서는 케이블TV 방송 런칭기념으로 뉴홈런2 100일분을 50% 할인된 특별행사가에 5월 8일 어버이날까지 판매하고 있으며, 자세한 내용은 쇼핑몰 싹(www.sark.co.kr, 1644-5660)에서 확인 가능하다.  하루 한알! 지친 중년의 남성들이여! 활력을 되찾아 보자!  ▶ 리헬스 뉴홈런2 구매하기▶ 문의전화 1644-5660<이 기사는 본지 편집 방향과 다를 수 있으며, 해당기관에서 제공한 보도 자료입니다.>
#
#
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 남자에게 참 좋은데.. 뉴홈런2 중년남성 눈뜨게 하다!
# http://news.joins.com/article/19837125
#
#
# 100세 시대가 되면서 최고의 노후 대책은 건강이다. 하지만 요즘의 중년남성들은 과도한 스트레스와 체력 저하 등 말 못할 고민들만 늘어나고 있다. 나이를 먹을수록 금새 지치고, 화장실을 들락날락 거리고 다녀와도 개운하지 않다. 쫄쫄쫄~ 나오는 소변 전립선 때문에! 뚝뚝~ 떨어지는 지구력 때문에! 예전 같지 않은 에너지 떄문에! 남몰래 스트레스 받는 중년남성들이 많다. 중년남성들의 생활의 활력을, 고민을 개선하는 방법은 적절한 운동과 건강기능식품을 섭취 하는 것이다. 시중에는 수많은 건강기능식품들이 나와있다. 그 중에서도 ㈜한국코러스제약 건강기능식품사업부에서 심혈을 기울여 제조한 뉴홈런2는 전립선 건강과 지구력 증진에 도움을 줄 수 있고 정상적인 면역기능이 필요한 지친 성인남성들에게 활력을 줄 수 있다.‘뉴홈런2’는 정상적인 활력과 체력에 필요한 원료를 배합하여 식약처에서 정식으로 품목제조신고를 받음과 동시에 사전광고심의를 통과한 후 해외로 수출하는 건강기능식품이다. 뉴홈런2 : 2016 두바이 헬스케어 세계박람회전립선 건강과 지구력증진에 도움을 줄수 있는 점을 목표로한 ‘뉴홈런2’는 4가지 장점이 있다. 첫번째, 식약처 기능성인정원료를 사용하고 ㈜코러스제약에서 야심차게 만든 제품이라 믿을만하다는 점이다. 두번째, 중년남성 뿐만 아니라 30~40대 젊은 남성들까지도 자신감 넘치는 활력을 만들어줄 수 있고 정상적인 면역기능에 필요, 전립선건강, 지구력증진에 뛰어남을 강조한다. 세번째, 다양한 곳에서 뉴홈런2를 만나볼 수 있다. 백화점의 건강기능식품 코너에 입점이 되어있고, 인터넷 쇼핑몰도 운영중이며, 케이블TV에서도 소비자들과 만나고 있다. 네번째, 소비자들의 가격부담을 줄이고자 저마진 정책, 소비자가 만족할만한 저렴한 가격을 제시하였다. 공식쇼핑몰 싹에서는 케이블TV 방송 런칭기념으로 뉴홈런2 100일분을 50% 할인된 특별행사가에 5월 8일 어버이날까지 판매하고 있으며, 자세한 내용은 쇼핑몰 싹(www.sark.co.kr, 1644-5660)에서 확인 가능하다.   하루 한알! 지친 중년의 남성들이여! 활력을 되찾아 보자!  ▶ 리헬스 뉴홈런2 구매하기▶ 문의전화 1644-5660<이 기사는 본지 편집 방향과 다를 수 있으며, 해당기관에서 제공한 보도 자료입니다.>
#
#
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
